# %% [markdown]
# # <font color=blue>Assignments for "Imbalanced Data"</font>

# %% [markdown]
# Using the [dataset](https://sci2s.ugr.es/keel/dataset/data/imbalanced/cleveland-0_vs_4.zip) for the [risk of heart attack](https://sci2s.ugr.es/keel/dataset.php?cod=980) with class imbalance:
#
# 1. Create a logistic regression model and measure the performance of it.
# 2. By experimenting with different methods and class ratios; overcome class imbalance, determine the best performing method and class ratio.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.utils import resample

# %%
df = pd.read_csv('heartAttack.dat',skiprows = 18,error_bad_lines=False)
df.columns =['age', 'sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num'] 
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 1    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 2    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 3    57.0  0.0  4.0     120.0  354.0  0.0      0.0    163.0    1.0      0.6
# 4    57.0  1.0  4.0     140.0  192.0  0.0      0.0    148.0    0.0      0.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 171  64.0  1.0  4.0     145.0  212.0  0.0      2.0    132.0    0.0      2.0
# 172  38.0  1.0  1.0     120.0  231.0  0.0      0.0    182.0    1.0      3.8
# 173  61.0  1.0  4.0     138.0  166.0  0.0      2.0    125.0    1.0      3.6
# 174  58.0  1.0  4.0     114.0  318.0  0.0      1.0    140.0    0.0      4.4
# 175  70.0  1.0  4.0     145.0  174.0  0.0      0.0    125.0    1.0      2.6
#
#      slope   ca thal       num
# 0      3.0  0.0  3.0  negative
# 1      1.0  0.0  3.0  negative
# 2      1.0  0.0  3.0  negative
# 3      1.0  0.0  3.0  negative
# 4      2.0  0.0  6.0  negative
# ..     ...  ...  ...       ...
# 171    2.0  2.0  6.0  positive
# 172    2.0  0.0  7.0  positive
# 173    2.0  1.0  3.0  positive
# 174    3.0  3.0  6.0  positive
# 175    3.0  0.0  7.0  positive
#
# [176 rows x 14 columns]

# %%
def objColumn(row):
    if row == "negative":
        value = 0
    else:
        value = 1
    return value

# %%
df2 = df.num.apply(objColumn)
df.num = df2

# %%
df.ca.unique()
df.thal.unique()
# Out:
# array(['3.0', '6.0', '7.0', '<null>'], dtype=object)

# %%
df = df[df.ca != "<null>"]
df = df[df.thal != "<null>"]

# %% [markdown]
# ### Creating a logistic regression model for dataset

# %%
from sklearn.model_selection import train_test_split
import warnings
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
warnings.filterwarnings('ignore')

# %%
X = df.iloc[:,:-1]
y = df.num

# %%
X_train, X_test, y_train, y_test =  train_test_split(X, y, test_size=0.20, random_state=111)

# %%
logreg = LogisticRegression()

# %%
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### Analyzing results

# %%
preds_train = logreg.predict(X_train)
preds_test = logreg.predict(X_test)

# %%
print("Train Dataset")
print("Accuracy score: {:.3f}" .format(accuracy_score(y_test, preds_test)))
print(classification_report(y_train, preds_train))
# Out:
# Train Dataset
# Accuracy score: 0.914
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       128
#            1       1.00      0.78      0.88         9
#
#     accuracy                           0.99       137
#    macro avg       0.99      0.89      0.93       137
# weighted avg       0.99      0.99      0.98       137

# %%
print("Test Dataset")
print("Accuracy score: {:.3f}" .format(accuracy_score(y_test, preds_test)))
print(classification_report(y_test, preds_test))
# Out:
# Test Dataset
# Accuracy score: 0.914
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        31
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.91        35
#    macro avg       0.96      0.62      0.68        35
# weighted avg       0.92      0.91      0.89        35

# %% [markdown]
# **Results:** On train dataset recall is 0.78 which can be acceptable. However, on the test dataset recall is 0.25. Which means our model can catch only 1 out of 4 heart patient. That is a very low level. The model has to be improved. In the following sections different methods will be used to get better model and results.

# %% [markdown]
# ### Upscaling

# %%
heartAttack = df[df.num==1]
noHeartAttack = df[df.num==0]
up_ = resample(heartAttack, n_samples= len(noHeartAttack), random_state=10)

# %%
upscaled_df = pd.concat([up_, noHeartAttack])

# %%
upscaled_df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 172  38.0  1.0  1.0     120.0  231.0  0.0      0.0    182.0    1.0      3.8
# 167  63.0  0.0  4.0     150.0  407.0  0.0      2.0    154.0    0.0      4.0
# 163  60.0  1.0  4.0     130.0  206.0  0.0      2.0    132.0    1.0      2.4
# 164  65.0  0.0  4.0     150.0  225.0  0.0      2.0    114.0    0.0      1.0
# 174  58.0  1.0  4.0     114.0  318.0  0.0      1.0    140.0    0.0      4.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 158  71.0  0.0  4.0     112.0  149.0  0.0      0.0    125.0    0.0      1.6
# 159  66.0  0.0  3.0     146.0  278.0  0.0      2.0    152.0    0.0      0.0
# 160  58.0  0.0  4.0     130.0  197.0  0.0      0.0    131.0    0.0      0.6
# 161  35.0  1.0  2.0     122.0  192.0  0.0      0.0    174.0    0.0      0.0
# 162  56.0  1.0  2.0     120.0  240.0  0.0      0.0    169.0    0.0      0.0
#
#      slope   ca thal  num
# 172    2.0  0.0  7.0    1
# 167    2.0  3.0  7.0    1
# 163    2.0  2.0  7.0    1
# 164    2.0  3.0  7.0    1
# 174    3.0  3.0  6.0    1
# ..     ...  ...  ...  ...
# 158    2.0  0.0  3.0    0
# 159    2.0  1.0  3.0    0
# 160    2.0  0.0  3.0    0
# 161    1.0  0.0  3.0    0
# 162    3.0  0.0  3.0    0
#
# [318 rows x 14 columns]

# %%
X1 = upscaled_df.iloc[:,:-1]
y1 = upscaled_df.num

# %%
X_train1, X_test1, y_train1, y_test1 =  train_test_split(X1, y1, test_size=0.20, random_state=111)

# %%
logreg2 = LogisticRegression()

# %%
logreg2.fit(X_train1, y_train1)
# Out:
# LogisticRegression()

# %%
preds_train1 = logreg2.predict(X_train1)
preds_test1 = logreg2.predict(X_test1)

# %%
print("Train Dataset")
print("Accuracy score: {:.3f}" .format(accuracy_score(y_train1, preds_train1)))
print(classification_report(y_train1, preds_train1))
# Out:
# Train Dataset
# Accuracy score: 0.988
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       129
#            1       0.98      1.00      0.99       125
#
#     accuracy                           0.99       254
#    macro avg       0.99      0.99      0.99       254
# weighted avg       0.99      0.99      0.99       254

# %%
print("Test Dataset")
print("Accuracy score: {:.3f}" .format(accuracy_score(y_test1, preds_test1)))
print(classification_report(y_test1, preds_test1))
# Out:
# Test Dataset
# Accuracy score: 0.938
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        30
#            1       0.89      1.00      0.94        34
#
#     accuracy                           0.94        64
#    macro avg       0.95      0.93      0.94        64
# weighted avg       0.94      0.94      0.94        64

# %% [markdown]
# **Results:** Accuracy and recalls are increased both train and test data. Now our model is much better than the original.

# %% [markdown]
# ### Downscaling

# %%
heartAttack = df[df.num==1]
noHeartAttack = df[df.num==0]
down_ = resample(noHeartAttack, n_samples= len(heartAttack), random_state=10)

# %%
downscaled_df = pd.concat([down_, heartAttack])

# %%
downscaled_df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 9    48.0  0.0  3.0     130.0  275.0  0.0      0.0    139.0    0.0      0.2
# 127  51.0  0.0  3.0     120.0  295.0  0.0      2.0    157.0    0.0      0.6
# 15   66.0  0.0  1.0     150.0  226.0  0.0      0.0    114.0    0.0      2.6
# 65   51.0  1.0  4.0     140.0  261.0  0.0      2.0    186.0    1.0      0.0
# 115  47.0  1.0  4.0     112.0  204.0  0.0      0.0    143.0    0.0      0.1
# 125  57.0  1.0  4.0     110.0  201.0  0.0      0.0    126.0    1.0      1.5
# 160  58.0  0.0  4.0     130.0  197.0  0.0      0.0    131.0    0.0      0.6
# 161  35.0  1.0  2.0     122.0  192.0  0.0      0.0    174.0    0.0      0.0
# 115  47.0  1.0  4.0     112.0  204.0  0.0      0.0    143.0    0.0      0.1
# 8    54.0  1.0  4.0     140.0  239.0  0.0      0.0    160.0    0.0      1.2
# 74   60.0  0.0  3.0     102.0  318.0  0.0      0.0    160.0    0.0      0.0
# 0    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 40   52.0  1.0  2.0     120.0  325.0  0.0      0.0    172.0    0.0      0.2
# 163  60.0  1.0  4.0     130.0  206.0  0.0      2.0    132.0    1.0      2.4
# 164  65.0  0.0  4.0     150.0  225.0  0.0      2.0    114.0    0.0      1.0
# 165  58.0  1.0  3.0     112.0  230.0  0.0      2.0    165.0    0.0      2.5
# 166  50.0  1.0  4.0     150.0  243.0  0.0      2.0    128.0    0.0      2.6
# 167  63.0  0.0  4.0     150.0  407.0  0.0      2.0    154.0    0.0      4.0
# 168  57.0  1.0  4.0     165.0  289.0  1.0      2.0    124.0    0.0      1.0
# 169  55.0  1.0  4.0     160.0  289.0  0.0      2.0    145.0    1.0      0.8
# 170  77.0  1.0  4.0     125.0  304.0  0.0      2.0    162.0    1.0      0.0
# 171  64.0  1.0  4.0     145.0  212.0  0.0      2.0    132.0    0.0      2.0
# 172  38.0  1.0  1.0     120.0  231.0  0.0      0.0    182.0    1.0      3.8
# 173  61.0  1.0  4.0     138.0  166.0  0.0      2.0    125.0    1.0      3.6
# 174  58.0  1.0  4.0     114.0  318.0  0.0      1.0    140.0    0.0      4.4
# 175  70.0  1.0  4.0     145.0  174.0  0.0      0.0    125.0    1.0      2.6
#
#      slope   ca thal  num
# 9      1.0  0.0  3.0    0
# 127    1.0  0.0  3.0    0
# 15     3.0  0.0  3.0    0
# 65     1.0  0.0  3.0    0
# 115    1.0  0.0  3.0    0
# 125    2.0  0.0  6.0    0
# 160    2.0  0.0  3.0    0
# 161    1.0  0.0  3.0    0
# 115    1.0  0.0  3.0    0
# 8      1.0  0.0  3.0    0
# 74     1.0  1.0  3.0    0
# 0      3.0  0.0  3.0    0
# 40     1.0  0.0  3.0    0
# 163    2.0  2.0  7.0    1
# 164    2.0  3.0  7.0    1
# 165    2.0  1.0  7.0    1
# 166    2.0  0.0  7.0    1
# 167    2.0  3.0  7.0    1
# 168    2.0  3.0  7.0    1
# 169    2.0  1.0  7.0    1
# 170    1.0  3.0  3.0    1
# 171    2.0  2.0  6.0    1
# 172    2.0  0.0  7.0    1
# 173    2.0  1.0  3.0    1
# 174    3.0  3.0  6.0    1
# 175    3.0  0.0  7.0    1

# %%
X2 = downscaled_df.iloc[:,:-1]
y2 = downscaled_df.num

X_train2, X_test2, y_train2, y_test2 =  train_test_split(X2, y2, test_size=0.20, random_state=111)

# %%
logreg3 = LogisticRegression()

logreg3.fit(X_train2, y_train2)

preds_train2 = logreg3.predict(X_train2)
preds_test2 = logreg3.predict(X_test2)

# %%
print("Train Dataset")
print("Accuracy score: {:.3f}" .format(accuracy_score(y_train2, preds_train2)))
print(classification_report(y_train2, preds_train2))
# Out:
# Train Dataset
# Accuracy score: 1.000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        10
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
print("Test Dataset")
print("Accuracy score: {:.3f}" .format(accuracy_score(y_test2, preds_test2)))
print(classification_report(y_test2, preds_test2))
# Out:
# Test Dataset
# Accuracy score: 1.000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6

# %% [markdown]
# ### SMOTE

# %%
from imblearn.over_sampling import SMOTE, ADASYN

# %%
sm = SMOTE()

# %%
X_smote, y_smote = sm.fit_sample(X, y)

# %%
X_train3, X_test3, y_train3, y_test3 =  train_test_split(X_smote, y_smote, test_size=0.20, random_state=111)

logreg4 = LogisticRegression()

logreg4.fit(X_train3, y_train3)

preds_train3 = logreg4.predict(X_train3)
preds_test3 = logreg4.predict(X_test3)

# %%
print("Train Dataset")
print("Accuracy score: {:.3f}" .format(accuracy_score(y_train3, preds_train3)))
print(classification_report(y_train3, preds_train3))
# Out:
# Train Dataset
# Accuracy score: 0.988
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       129
#            1       0.98      1.00      0.99       125
#
#     accuracy                           0.99       254
#    macro avg       0.99      0.99      0.99       254
# weighted avg       0.99      0.99      0.99       254

# %%
print("Test Dataset")
print("Accuracy score: {:.3f}" .format(accuracy_score(y_test3, preds_test3)))
print(classification_report(y_test3, preds_test3))
# Out:
# Test Dataset
# Accuracy score: 0.938
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        30
#            1       0.89      1.00      0.94        34
#
#     accuracy                           0.94        64
#    macro avg       0.95      0.93      0.94        64
# weighted avg       0.94      0.94      0.94        64

# %% [markdown]
# ### ADASYN

# %%
ad = ADASYN()

# %%
X_ad, y_ad = ad.fit_sample(X, y)

# %%
X_train4, X_test4, y_train4, y_test4 =  train_test_split(X_ad, y_ad, test_size=0.20, random_state=111)

logreg5 = LogisticRegression()

logreg5.fit(X_train4, y_train4)

preds_train4 = logreg5.predict(X_train4)
preds_test4 = logreg5.predict(X_test4)

# %%
print("Train Dataset")
print("Accuracy score: {:.3f}" .format(accuracy_score(y_train4, preds_train4)))
print(classification_report(y_train4, preds_train4))
# Out:
# Train Dataset
# Accuracy score: 0.988
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       129
#            1       0.98      1.00      0.99       125
#
#     accuracy                           0.99       254
#    macro avg       0.99      0.99      0.99       254
# weighted avg       0.99      0.99      0.99       254

# %%
print("Test Dataset")
print("Accuracy score: {:.3f}" .format(accuracy_score(y_test4, preds_test4)))
print(classification_report(y_test4, preds_test4))
# Out:
# Test Dataset
# Accuracy score: 0.938
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        30
#            1       0.89      1.00      0.94        34
#
#     accuracy                           0.94        64
#    macro avg       0.95      0.93      0.94        64
# weighted avg       0.94      0.94      0.94        64

# %% [markdown]
# **Final Comment:** Downsizing negative results to positive result number model has the best model according to our train and test data. Downsizin can be chosen for this data.
